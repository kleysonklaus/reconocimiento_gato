# %%
### JUGANDO CON LA INICIALIZACION DE LOS PESOS, ALPHA Y NUMERO DE ITERACIONES
### POR AHORA SE ALTERO LIGERAMENTE EL ALGORITMO
### SOLO SE CAMBIO LOS PARAMETROS INDICADOS (BIAS, ALPHA E ITERACIONES)
### SE PROBO CON LO SIGUIENTE:
### BIAS = 10
### ALPHA = 0.0002
### ITERACIONES = 500 000
_ALPHA = 0.0002
_ITERACIONES = 500000
### 
### NOTA: SE MOSTRARÁ AVANCES CADA "3 000" ITERACIONES, ESTO PARA AHORRAR TIEMPO DE PROCESAMIENTO MIENTRAS IMPRIME
###

# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import scipy
from PIL import Image
from scipy import ndimage
def load_dataset():
    train_dataset = h5py.File('datasets/train_catvnoncat.h5', "r")
    train_set_x_orig = np.array(train_dataset["train_set_x"][:])
    train_set_y_orig = np.array(train_dataset["train_set_y"][:])#---
    test_dataset = h5py.File('datasets/test_catvnoncat.h5', "r")
    test_set_x_orig = np.array(test_dataset["test_set_x"][:])
    test_set_y_orig = np.array(test_dataset["test_set_y"][:])#---
    classes = np.array(test_dataset["list_classes"][:])
    train_set_y_orig = train_set_y_orig.reshape((1, train_set_y_orig.shape[0]))
    test_set_y_orig = test_set_y_orig.reshape((1, test_set_y_orig.shape[0]))#---
    return train_set_x_orig, train_set_y_orig, test_set_x_orig, test_set_y_orig, classes
#-------------------------------------------------------------------------------------------
# from random import randint, random , uniform
# def inicializar_zeros(dimension):
#     w = np.zeros((dimension, 1),dtype='float')
#     b = 0
#     for i in range (dimension):
#         w[i,0] = uniform(0,1)
#     assert(w.shape == (dimension,1))
#     assert(isinstance(b,float) or isinstance(b,int))
#     return w ,b
######################################3
from random import randint, random , uniform
def inicializar_zeros(dimension):
    #w = np.zeros((dimension, 1),dtype='float')
    w = np.ones((dimension , 1),dtype='float')
    b = 10
    assert(w.shape == (dimension,1))
    assert(isinstance(b,float) or isinstance(b,int))
    return w ,b
#-------------------------------------------------------------------------------------------
def sigmoide(self):
    return 1 / (1 + np.exp(-self))
#-------------------------------------------------------------------------------------------
def propagate(w, b, X, Y):
    m = X.shape[1]
    A = sigmoide(np.dot(w.T, X) + b)
    cost = (-1/m)*np.sum((Y*np.log(A)+ (1-Y)*np.log(1-A)), axis = 1)
    dw = (1/m)*np.dot(X,(A-Y).T)
    db = (1/m)*np.sum(A-Y)
    assert(dw.shape == w.shape)
    assert(db.dtype == float)
    cost = np.squeeze(cost)
    assert(cost.shape == ())
    grads = {"dw": dw, "db": db}
    return grads, cost
#-------------------------------------------------------------------------------------------
def optimizar(w, b, X, Y, num_iterations, learning_rate, print_cost = False):
    costs = []
    for i in range(num_iterations):
        grads, cost = propagate(w, b, X, Y)
        dw = grads["dw"]
        db = grads["db"]
        w = w - (learning_rate * dw)
        b = b - (learning_rate * db)
        if i % 100 == 0:
            costs.append(cost)
        if print_cost and i % 3000 == 0:
            print ("Costo despues de iteracion %i: %f" %(i, cost))
    params = {"w": w, "b": b}
    grads = {"dw": dw, "db": db}
    return params, grads, costs
#-------------------------------------------------------------------------------------------
def predict(w, b, X):
    m = X.shape[1]
    Y_prediction = np.zeros((1,m))
    w = w.reshape(X.shape[0], 1)
    A = sigmoide(np.dot(w.T, X)+b)
    for i in range(A.shape[1]):
        if (A[0,i] <= 0.5):
            Y_prediction[0,i] = 0
        else:
            Y_prediction[0,i] = 1
    assert(Y_prediction.shape == (1, m))
    return Y_prediction
#-------------------------------------------------------------------------------------------
def model(X_train, Y_train, X_test, Y_test, num_iterations = 2000, learning_rate = 0.5, print_cost =False):
    w, b = inicializar_zeros(X_train.shape[0])
    parameters, grads, costs = optimizar(w, b, X_train, Y_train, num_iterations, learning_rate, print_cost)
    w = parameters["w"]
    b = parameters["b"]
    Y_prediction_test = predict(w, b, X_test)
    Y_prediction_train = predict(w, b, X_train)
    print("train accuracy: {} %".format(100 - np.mean(np.abs(Y_prediction_train - Y_train)) * 100))
    print("test accuracy: {} %".format(100 - np.mean(np.abs(Y_prediction_test - Y_test)) * 100))
    d = {"costs": costs, "Y_prediction_test": Y_prediction_test,
    "Y_prediction_train" : Y_prediction_train, "w" : w, "b" : b,
    "learning_rate" : learning_rate, "num_iterations": num_iterations}
    return d

# %%
train_set_x_orig, train_set_y, test_set_x_orig, test_set_y, classes = load_dataset()
train_set_x_orig_flatten = train_set_x_orig.reshape (train_set_x_orig.shape [0], -1).T
test_set_x_orig_flatten = test_set_x_orig.reshape (test_set_x_orig.shape [0], -1).T
train_set_x = train_set_x_orig_flatten/255
test_set_x = test_set_x_orig_flatten/255

# %%
d = model(train_set_x, train_set_y, test_set_x, test_set_y, _ITERACIONES, _ALPHA ,print_cost = True)
# Out:
# Costo despues de iteracion 0: 6.555069
# Costo despues de iteracion 3000: 0.892014
# Costo despues de iteracion 6000: 0.720905
# Costo despues de iteracion 9000: 0.604481
# Costo despues de iteracion 12000: 0.519293
# Costo despues de iteracion 15000: 0.453700
# Costo despues de iteracion 18000: 0.401496
# Costo despues de iteracion 21000: 0.358887
# Costo despues de iteracion 24000: 0.323385
# Costo despues de iteracion 27000: 0.293350
# Costo despues de iteracion 30000: 0.267704
# Costo despues de iteracion 33000: 0.245692
# Costo despues de iteracion 36000: 0.226703
# Costo despues de iteracion 39000: 0.210209
# Costo despues de iteracion 42000: 0.195766
# Costo despues de iteracion 45000: 0.183022
# Costo despues de iteracion 48000: 0.171698
# Costo despues de iteracion 51000: 0.161573
# Costo despues de iteracion 54000: 0.152471
# Costo despues de iteracion 57000: 0.144250
# Costo despues de iteracion 60000: 0.136795
# Costo despues de iteracion 63000: 0.130010
# Costo despues de iteracion 66000: 0.123818
# Costo despues de iteracion 69000: 0.118150
# Costo despues de iteracion 72000: 0.112948
# Costo despues de iteracion 75000: 0.108163
# Costo despues de iteracion 78000: 0.103751
# Costo despues de iteracion 81000: 0.099671
# Costo despues de iteracion 84000: 0.095892
# Costo despues de iteracion 87000: 0.092382
# Costo despues de iteracion 90000: 0.089114
# Costo despues de iteracion 93000: 0.086066
# Costo despues de iteracion 96000: 0.083217
# Costo despues de iteracion 99000: 0.080548
# Costo despues de iteracion 102000: 0.078043
# Costo despues de iteracion 105000: 0.075688
# Costo despues de iteracion 108000: 0.073469
# Costo despues de iteracion 111000: 0.071376
# Costo despues de iteracion 114000: 0.069398
# Costo despues de iteracion 117000: 0.067527
# Costo despues de iteracion 120000: 0.065753
# Costo despues de iteracion 123000: 0.064069
# Costo despues de iteracion 126000: 0.062469
# Costo despues de iteracion 129000: 0.060946
# Costo despues de iteracion 132000: 0.059496
# Costo despues de iteracion 135000: 0.058113
# Costo despues de iteracion 138000: 0.056792
# Costo despues de iteracion 141000: 0.055530
# Costo despues de iteracion 144000: 0.054322
# Costo despues de iteracion 147000: 0.053166
# Costo despues de iteracion 150000: 0.052058
# Costo despues de iteracion 153000: 0.050994
# Costo despues de iteracion 156000: 0.049974
# Costo despues de iteracion 159000: 0.048993
# Costo despues de iteracion 162000: 0.048049
# Costo despues de iteracion 165000: 0.047142
# Costo despues de iteracion 168000: 0.046267
# Costo despues de iteracion 171000: 0.045425
# Costo despues de iteracion 174000: 0.044612
# Costo despues de iteracion 177000: 0.043828
# Costo despues de iteracion 180000: 0.043071
# Costo despues de iteracion 183000: 0.042340
# Costo despues de iteracion 186000: 0.041632
# Costo despues de iteracion 189000: 0.040948
# Costo despues de iteracion 192000: 0.040286
# Costo despues de iteracion 195000: 0.039645
# Costo despues de iteracion 198000: 0.039024
# Costo despues de iteracion 201000: 0.038423
# Costo despues de iteracion 204000: 0.037839
# Costo despues de iteracion 207000: 0.037273
# Costo despues de iteracion 210000: 0.036723
# Costo despues de iteracion 213000: 0.036189
# Costo despues de iteracion 216000: 0.035671
# Costo despues de iteracion 219000: 0.035167
# Costo despues de iteracion 222000: 0.034677
# Costo despues de iteracion 225000: 0.034200
# Costo despues de iteracion 228000: 0.033737
# Costo despues de iteracion 231000: 0.033285
# Costo despues de iteracion 234000: 0.032846
# Costo despues de iteracion 237000: 0.032418
# Costo despues de iteracion 240000: 0.032001
# Costo despues de iteracion 243000: 0.031594
# Costo despues de iteracion 246000: 0.031198
# Costo despues de iteracion 249000: 0.030811
# Costo despues de iteracion 252000: 0.030434
# Costo despues de iteracion 255000: 0.030066
# Costo despues de iteracion 258000: 0.029707
# Costo despues de iteracion 261000: 0.029356
# Costo despues de iteracion 264000: 0.029014
# Costo despues de iteracion 267000: 0.028679
# Costo despues de iteracion 270000: 0.028352
# Costo despues de iteracion 273000: 0.028032
# Costo despues de iteracion 276000: 0.027719
# Costo despues de iteracion 279000: 0.027413
# Costo despues de iteracion 282000: 0.027114
# Costo despues de iteracion 285000: 0.026822
# Costo despues de iteracion 288000: 0.026535
# Costo despues de iteracion 291000: 0.026255
# Costo despues de iteracion 294000: 0.025980
# Costo despues de iteracion 297000: 0.025711
# Costo despues de iteracion 300000: 0.025448
# Costo despues de iteracion 303000: 0.025190
# Costo despues de iteracion 306000: 0.024937
# Costo despues de iteracion 309000: 0.024689
# Costo despues de iteracion 312000: 0.024446
# Costo despues de iteracion 315000: 0.024208
# Costo despues de iteracion 318000: 0.023974
# Costo despues de iteracion 321000: 0.023745
# Costo despues de iteracion 324000: 0.023520
# Costo despues de iteracion 327000: 0.023299
# Costo despues de iteracion 330000: 0.023082
# Costo despues de iteracion 333000: 0.022870
# Costo despues de iteracion 336000: 0.022661
# Costo despues de iteracion 339000: 0.022456
# Costo despues de iteracion 342000: 0.022255
# Costo despues de iteracion 345000: 0.022057
# Costo despues de iteracion 348000: 0.021863
# Costo despues de iteracion 351000: 0.021672
# Costo despues de iteracion 354000: 0.021485
# Costo despues de iteracion 357000: 0.021300
# Costo despues de iteracion 360000: 0.021119
# Costo despues de iteracion 363000: 0.020941
# Costo despues de iteracion 366000: 0.020766
# Costo despues de iteracion 369000: 0.020593
# Costo despues de iteracion 372000: 0.020424
# Costo despues de iteracion 375000: 0.020257
# Costo despues de iteracion 378000: 0.020093
# Costo despues de iteracion 381000: 0.019932
# Costo despues de iteracion 384000: 0.019773
# Costo despues de iteracion 387000: 0.019617
# Costo despues de iteracion 390000: 0.019463
# Costo despues de iteracion 393000: 0.019312
# Costo despues de iteracion 396000: 0.019163
# Costo despues de iteracion 399000: 0.019016
# Costo despues de iteracion 402000: 0.018871
# Costo despues de iteracion 405000: 0.018729
# Costo despues de iteracion 408000: 0.018589
# Costo despues de iteracion 411000: 0.018451
# Costo despues de iteracion 414000: 0.018314
# Costo despues de iteracion 417000: 0.018180
# Costo despues de iteracion 420000: 0.018048
# Costo despues de iteracion 423000: 0.017918
# Costo despues de iteracion 426000: 0.017789
# Costo despues de iteracion 429000: 0.017663
# Costo despues de iteracion 432000: 0.017538
# Costo despues de iteracion 435000: 0.017415
# Costo despues de iteracion 438000: 0.017294
# Costo despues de iteracion 441000: 0.017174
# Costo despues de iteracion 444000: 0.017056
# Costo despues de iteracion 447000: 0.016940
# Costo despues de iteracion 450000: 0.016825
# Costo despues de iteracion 453000: 0.016712
# Costo despues de iteracion 456000: 0.016600
# Costo despues de iteracion 459000: 0.016490
# Costo despues de iteracion 462000: 0.016381
# Costo despues de iteracion 465000: 0.016274
# Costo despues de iteracion 468000: 0.016168
# Costo despues de iteracion 471000: 0.016063
# Costo despues de iteracion 474000: 0.015960
# Costo despues de iteracion 477000: 0.015858
# Costo despues de iteracion 480000: 0.015757
# Costo despues de iteracion 483000: 0.015658
# Costo despues de iteracion 486000: 0.015560
# Costo despues de iteracion 489000: 0.015463
# Costo despues de iteracion 492000: 0.015367
# Costo despues de iteracion 495000: 0.015273
# Costo despues de iteracion 498000: 0.015180
# train accuracy: 100.0 %
# test accuracy: 60.0 %

# %%
costs = np.squeeze(d['costs'])
plt.plot(costs)
plt.ylabel('costo')
plt.xlabel('iteraciones (por miles)')
plt.title("ALPHA =" + str(d["learning_rate"]))
plt.show()

# %%
learning_rates = [0.01, 0.001, 0.0002]
models = {}
for i in learning_rates:
    print ("learning rate is: " + str(i))
    models[str(i)] = model(train_set_x, train_set_y, test_set_x, test_set_y, num_iterations = 1500,
learning_rate = i, print_cost = False)
print ('\n' + "-------------------------------------------------------" + '\n')
for i in learning_rates:
    plt.plot(np.squeeze(models[str(i)]["costs"]), label= str(models[str(i)]["learning_rate"]))
plt.ylabel('cost')
plt.xlabel('iterations (hundreds)')
legend = plt.legend(loc='upper center', shadow=True)
frame = legend.get_frame()
frame.set_facecolor('0.90')
plt.show()
# Out:
# learning rate is: 0.01
# train accuracy: 98.08612440191388 %
# test accuracy: 64.0 %
# learning rate is: 0.001
# train accuracy: 75.11961722488039 %
# test accuracy: 48.0 %
# learning rate is: 0.0002
# train accuracy: 60.76555023923445 %
# test accuracy: 40.0 %
#
# -------------------------------------------------------

# %%
### probar con tu imagen
my_image = "delfin1.jpg"
fname = "prueba_gatos/" + my_image
image = np.array(ndimage.imread(fname, flatten=False))
#image = np.array(Image.fromarray(fname).resize(), flatten=False)
num_px = train_set_x_orig.shape[2]
my_image = scipy.misc.imresize(image, size=(num_px,num_px)).reshape((1, num_px*num_px*3)).T

my_predicted_image = predict(d["w"], d["b"], my_image)
plt.imshow(image)
print("y = " + str(np.squeeze(my_predicted_image)) + ", prediccion de algoritmo = \"" +
classes[int(np.squeeze(my_predicted_image)),].decode("utf-8") + "\" imagen")
# Out:
# C:\Users\Toshiba\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0.
# Use ``matplotlib.pyplot.imread`` instead.
#   after removing the cwd from sys.path.
# C:\Users\Toshiba\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
# Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
#   import sys
# y = 0.0, prediccion de algoritmo = "non-cat" imagen

# %%
### probar con tu imagen
my_image = "gato2.jpg"
fname = "prueba_gatos/" + my_image
image = np.array(ndimage.imread(fname, flatten=False))
#image = np.array(Image.fromarray(fname).resize(), flatten=False)
num_px = train_set_x_orig.shape[2]
my_image = scipy.misc.imresize(image, size=(num_px,num_px)).reshape((1, num_px*num_px*3)).T

my_predicted_image = predict(d["w"], d["b"], my_image)
plt.imshow(image)
print("y = " + str(np.squeeze(my_predicted_image)) + ", prediccion de algoritmo = \"" +
classes[int(np.squeeze(my_predicted_image)),].decode("utf-8") + "\" imagen")
# Out:
# C:\Users\Toshiba\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0.
# Use ``matplotlib.pyplot.imread`` instead.
#   after removing the cwd from sys.path.
# C:\Users\Toshiba\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
# Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
#   import sys
# y = 0.0, prediccion de algoritmo = "non-cat" imagen
